# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the train dataset
df_1 = pd.read_csv('../data/train.csv')
df_1
# Out:
#                 date_time  deg_C  relative_humidity  absolute_humidity  \
# 0     2010-03-10 18:00:00   13.1               46.0             0.7578
# 1     2010-03-10 19:00:00   13.2               45.3             0.7255
# 2     2010-03-10 20:00:00   12.6               56.2             0.7502
# 3     2010-03-10 21:00:00   11.0               62.4             0.7867
# 4     2010-03-10 22:00:00   11.9               59.0             0.7888
# ...                   ...    ...                ...                ...
# 7106  2010-12-31 20:00:00    9.2               32.0             0.3871
# 7107  2010-12-31 21:00:00    9.1               33.2             0.3766
# 7108  2010-12-31 22:00:00    9.6               34.6             0.4310
# 7109  2010-12-31 23:00:00    8.0               40.7             0.4085
# 7110  2011-01-01 00:00:00    8.0               41.3             0.4375
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0       1387.2    1087.8    1056.0    1742.8    1293.4
# 1       1279.1     888.2    1197.5    1449.9    1010.9
# 2       1331.9     929.6    1060.2    1586.1    1117.0
# 3       1321.0     929.0    1102.9    1536.5    1263.2
# 4       1272.0     852.7    1180.9    1415.5    1132.2
# ...        ...       ...       ...       ...       ...
# 7106    1000.5     811.2     873.0     909.0     910.5
# 7107    1022.7     790.0     951.6     912.9     903.4
# 7108    1044.4     767.3     861.9     889.2    1159.1
# 7109     952.8     691.9     908.5     917.0    1206.3
# 7110    1108.8     745.7     797.1     880.0    1273.1
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides
# 0                        2.5            12.0                   167.7
# 1                        2.1             9.9                    98.9
# 2                        2.2             9.2                   127.1
# 3                        2.2             9.7                   177.2
# 4                        1.5             6.4                   121.8
# ...                      ...             ...                     ...
# 7106                     1.3             5.1                   191.1
# 7107                     1.4             5.8                   221.3
# 7108                     1.6             5.2                   227.4
# 7109                     1.5             4.6                   199.8
# 7110                     1.4             4.1                   186.5
#
# [7111 rows x 12 columns]

# %%
# load the test dataset
df_2 = pd.read_csv('../data/test.csv')
df_2
# Out:
#                 date_time  deg_C  relative_humidity  absolute_humidity  \
# 0     2011-01-01 00:00:00    8.0               41.3             0.4375
# 1     2011-01-01 01:00:00    5.1               51.7             0.4564
# 2     2011-01-01 02:00:00    5.8               51.5             0.4689
# 3     2011-01-01 03:00:00    5.0               52.3             0.4693
# 4     2011-01-01 04:00:00    4.5               57.5             0.4650
# ...                   ...    ...                ...                ...
# 2242  2011-04-04 10:00:00   23.2               28.7             0.7568
# 2243  2011-04-04 11:00:00   24.5               22.5             0.7119
# 2244  2011-04-04 12:00:00   26.6               19.0             0.6406
# 2245  2011-04-04 13:00:00   29.1               12.7             0.5139
# 2246  2011-04-04 14:00:00   27.9               13.5             0.5028
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5
# 0       1108.8     745.7     797.1     880.0    1273.1
# 1       1249.5     864.9     687.9     972.8    1714.0
# 2       1102.6     878.0     693.7     941.9    1300.8
# 3       1139.7     916.2     725.6    1011.0    1283.0
# 4       1022.4     838.5     871.5     967.0    1142.3
# ...        ...       ...       ...       ...       ...
# 2242    1340.3    1023.9     522.8    1374.0    1659.8
# 2243    1232.8     955.1     616.1    1226.1    1269.0
# 2244    1187.7    1052.4     572.8    1253.4    1081.1
# 2245    1053.2    1009.0     702.0    1009.8     808.5
# 2246    1124.6    1078.4     608.2    1061.3     816.0
#
# [2247 rows x 9 columns]

# %% [markdown]
# <h3 style="color:blue"><b> 1. CONCAT <b> </h3>

# %%
# concatenate the two datasets vertically
df_full = pd.concat([df_1, df_2], axis=0)
# reset the index
df_full.reset_index(drop=True, inplace=True)
df_full
# Out:
#                 date_time  deg_C  relative_humidity  absolute_humidity  \
# 0     2010-03-10 18:00:00   13.1               46.0             0.7578
# 1     2010-03-10 19:00:00   13.2               45.3             0.7255
# 2     2010-03-10 20:00:00   12.6               56.2             0.7502
# 3     2010-03-10 21:00:00   11.0               62.4             0.7867
# 4     2010-03-10 22:00:00   11.9               59.0             0.7888
# ...                   ...    ...                ...                ...
# 9353  2011-04-04 10:00:00   23.2               28.7             0.7568
# 9354  2011-04-04 11:00:00   24.5               22.5             0.7119
# 9355  2011-04-04 12:00:00   26.6               19.0             0.6406
# 9356  2011-04-04 13:00:00   29.1               12.7             0.5139
# 9357  2011-04-04 14:00:00   27.9               13.5             0.5028
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0       1387.2    1087.8    1056.0    1742.8    1293.4
# 1       1279.1     888.2    1197.5    1449.9    1010.9
# 2       1331.9     929.6    1060.2    1586.1    1117.0
# 3       1321.0     929.0    1102.9    1536.5    1263.2
# 4       1272.0     852.7    1180.9    1415.5    1132.2
# ...        ...       ...       ...       ...       ...
# 9353    1340.3    1023.9     522.8    1374.0    1659.8
# 9354    1232.8     955.1     616.1    1226.1    1269.0
# 9355    1187.7    1052.4     572.8    1253.4    1081.1
# 9356    1053.2    1009.0     702.0    1009.8     808.5
# 9357    1124.6    1078.4     608.2    1061.3     816.0
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides
# 0                        2.5            12.0                   167.7
# 1                        2.1             9.9                    98.9
# 2                        2.2             9.2                   127.1
# 3                        2.2             9.7                   177.2
# 4                        1.5             6.4                   121.8
# ...                      ...             ...                     ...
# 9353                     NaN             NaN                     NaN
# 9354                     NaN             NaN                     NaN
# 9355                     NaN             NaN                     NaN
# 9356                     NaN             NaN                     NaN
# 9357                     NaN             NaN                     NaN
#
# [9358 rows x 12 columns]

# %%
### fill the missing values with random values of the same column
def fill_missing(col):
    non_nan_values = col.dropna()
    return col.apply(lambda x: x if pd.notnull(x) else np.random.choice(non_nan_values))

# fill the missing values in the columns
df_full['target_carbon_monoxide'] = fill_missing(df_full['target_carbon_monoxide'])
df_full['target_benzene'] = fill_missing(df_full['target_benzene'])
df_full['target_nitrogen_oxides'] = fill_missing(df_full['target_nitrogen_oxides'])
df_full = df_full.copy()
df_full
# Out:
#                 date_time  deg_C  relative_humidity  absolute_humidity  \
# 0     2010-03-10 18:00:00   13.1               46.0             0.7578
# 1     2010-03-10 19:00:00   13.2               45.3             0.7255
# 2     2010-03-10 20:00:00   12.6               56.2             0.7502
# 3     2010-03-10 21:00:00   11.0               62.4             0.7867
# 4     2010-03-10 22:00:00   11.9               59.0             0.7888
# ...                   ...    ...                ...                ...
# 9353  2011-04-04 10:00:00   23.2               28.7             0.7568
# 9354  2011-04-04 11:00:00   24.5               22.5             0.7119
# 9355  2011-04-04 12:00:00   26.6               19.0             0.6406
# 9356  2011-04-04 13:00:00   29.1               12.7             0.5139
# 9357  2011-04-04 14:00:00   27.9               13.5             0.5028
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0       1387.2    1087.8    1056.0    1742.8    1293.4
# 1       1279.1     888.2    1197.5    1449.9    1010.9
# 2       1331.9     929.6    1060.2    1586.1    1117.0
# 3       1321.0     929.0    1102.9    1536.5    1263.2
# 4       1272.0     852.7    1180.9    1415.5    1132.2
# ...        ...       ...       ...       ...       ...
# 9353    1340.3    1023.9     522.8    1374.0    1659.8
# 9354    1232.8     955.1     616.1    1226.1    1269.0
# 9355    1187.7    1052.4     572.8    1253.4    1081.1
# 9356    1053.2    1009.0     702.0    1009.8     808.5
# 9357    1124.6    1078.4     608.2    1061.3     816.0
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides
# 0                        2.5            12.0                   167.7
# 1                        2.1             9.9                    98.9
# 2                        2.2             9.2                   127.1
# 3                        2.2             9.7                   177.2
# 4                        1.5             6.4                   121.8
# ...                      ...             ...                     ...
# 9353                     1.6             1.5                   319.0
# 9354                     4.8            15.2                    67.0
# 9355                     2.3             2.0                    83.7
# 9356                     0.7            22.9                    38.6
# 9357                     0.4             6.0                   125.2
#
# [9358 rows x 12 columns]

# %%
# save the data
df_full.to_csv('../data/df_full.csv', index=False)

# %% [markdown]
# <h3 style="color:blue"><b> 2. FILTER </b></h3>

# %%
# Ensure the date_time column is in datetime format
df_full['date_time'] = pd.to_datetime(df_full['date_time'])

# %%
# Filter for weekdays (0 = Monday to 4 = Friday), relative humidity > 50, and absolute humidity < 1.4
df_filtered = df_full[
    (df_full['date_time'].dt.weekday <= 4) &  # Weekdays only
    (df_full['relative_humidity'] > 50) &  # Relative humidity > 50
    (df_full['absolute_humidity'] < 1.4)  # Absolute humidity < 1.4
].copy()

# Reset the index
df_filtered.reset_index(drop=True, inplace=True)
df_filtered
# Out:
#                date_time  deg_C  relative_humidity  absolute_humidity  \
# 0    2010-03-10 20:00:00   12.6               56.2             0.7502
# 1    2010-03-10 21:00:00   11.0               62.4             0.7867
# 2    2010-03-10 22:00:00   11.9               59.0             0.7888
# 3    2010-03-10 23:00:00   11.2               56.8             0.7848
# 4    2010-03-11 00:00:00   10.7               55.7             0.7603
# ...                  ...    ...                ...                ...
# 2315 2011-04-04 03:00:00   11.0               56.0             0.7888
# 2316 2011-04-04 04:00:00   11.0               57.7             0.7743
# 2317 2011-04-04 05:00:00   10.7               61.7             0.7550
# 2318 2011-04-04 06:00:00    9.5               66.9             0.7531
# 2319 2011-04-04 07:00:00    9.1               60.7             0.7446
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0       1331.9     929.6    1060.2    1586.1    1117.0
# 1       1321.0     929.0    1102.9    1536.5    1263.2
# 2       1272.0     852.7    1180.9    1415.5    1132.2
# 3       1220.9     697.5    1417.2    1462.6     949.0
# 4       1244.2     669.3    1491.2    1413.0     769.6
# ...        ...       ...       ...       ...       ...
# 2315     878.1     538.5    1078.4     905.8     565.5
# 2316     907.2     458.9    1071.4     958.0     454.8
# 2317     941.3     549.1    1098.5     947.5     549.1
# 2318     989.8     686.2     805.6    1061.3     841.6
# 2319    1411.7    1135.5     474.7    1584.0    1515.3
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides
# 0                        2.2             9.2                   127.1
# 1                        2.2             9.7                   177.2
# 2                        1.5             6.4                   121.8
# 3                        1.2             4.4                    88.1
# 4                        1.2             3.7                    59.5
# ...                      ...             ...                     ...
# 2315                     3.9            13.0                   186.1
# 2316                     3.3            10.5                   126.4
# 2317                     1.8             8.2                   251.7
# 2318                     0.8            10.2                   259.3
# 2319                     0.7             2.9                   129.6
#
# [2320 rows x 12 columns]

# %% [markdown]
# <h3 style="color:blue"><b> 3. APPLY </b></h3>

# %%
# A new(dummy) column for year-month to help with grouping and averaging of monthly sensor_4 values
# I would remove this column before saving
df_filtered['year_month'] = df_filtered['date_time'].dt.to_period('M')  # Year-Month as 'YYYY-MM'

# %%
# Mean of 'sensor_4' for each year-month
monthly_mean_sensor_4 = df_filtered.groupby('year_month')['sensor_4'].transform('mean')

# %%
monthly_mean_sensor_4
# Out:
# 0       1558.833333
# 1       1558.833333
# 2       1558.833333
# 3       1558.833333
# 4       1558.833333
#            ...
# 2315    1042.700000
# 2316    1042.700000
# 2317    1042.700000
# 2318    1042.700000
# 2319    1042.700000
# Name: sensor_4, Length: 2320, dtype: float64

# %%
# median of 'sensor_4'
sensor_4_median = df_filtered['sensor_4'].median()
sensor_4_median
# Out:
# 1356.45

# %%
# creating column with name 'apply_step3' based on the condition
df_filtered['apply_step3'] = np.where(
    df_filtered['sensor_4'] < sensor_4_median,
    df_filtered['sensor_2'] * df_filtered['sensor_3'],  # If sensor_4 < median
    df_filtered['sensor_2'] * df_filtered['sensor_4'] - monthly_mean_sensor_4  # Else
)

# %%
# drop the 'year_month' (dummy) column
df_filtered.drop(columns=['year_month'], inplace=True)
df_filtered
# Out:
#                date_time  deg_C  relative_humidity  absolute_humidity  \
# 0    2010-03-10 20:00:00   12.6               56.2             0.7502
# 1    2010-03-10 21:00:00   11.0               62.4             0.7867
# 2    2010-03-10 22:00:00   11.9               59.0             0.7888
# 3    2010-03-10 23:00:00   11.2               56.8             0.7848
# 4    2010-03-11 00:00:00   10.7               55.7             0.7603
# ...                  ...    ...                ...                ...
# 2315 2011-04-04 03:00:00   11.0               56.0             0.7888
# 2316 2011-04-04 04:00:00   11.0               57.7             0.7743
# 2317 2011-04-04 05:00:00   10.7               61.7             0.7550
# 2318 2011-04-04 06:00:00    9.5               66.9             0.7531
# 2319 2011-04-04 07:00:00    9.1               60.7             0.7446
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0       1331.9     929.6    1060.2    1586.1    1117.0
# 1       1321.0     929.0    1102.9    1536.5    1263.2
# 2       1272.0     852.7    1180.9    1415.5    1132.2
# 3       1220.9     697.5    1417.2    1462.6     949.0
# 4       1244.2     669.3    1491.2    1413.0     769.6
# ...        ...       ...       ...       ...       ...
# 2315     878.1     538.5    1078.4     905.8     565.5
# 2316     907.2     458.9    1071.4     958.0     454.8
# 2317     941.3     549.1    1098.5     947.5     549.1
# 2318     989.8     686.2     805.6    1061.3     841.6
# 2319    1411.7    1135.5     474.7    1584.0    1515.3
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides  \
# 0                        2.2             9.2                   127.1
# 1                        2.2             9.7                   177.2
# 2                        1.5             6.4                   121.8
# 3                        1.2             4.4                    88.1
# 4                        1.2             3.7                    59.5
# ...                      ...             ...                     ...
# 2315                     3.9            13.0                   186.1
# 2316                     3.3            10.5                   126.4
# 2317                     1.8             8.2                   251.7
# 2318                     0.8            10.2                   259.3
# 2319                     0.7             2.9                   129.6
#
#        apply_step3
# 0     1.472880e+06
# 1     1.425850e+06
# 2     1.205438e+06
# 3     1.018605e+06
# 4     9.441621e+05
# ...            ...
# 2315  5.807184e+05
# 2316  4.916655e+05
# 2317  6.031863e+05
# 2318  5.528027e+05
# 2319  1.797589e+06
#
# [2320 rows x 13 columns]

# %%
# save df_filtered table
df_filtered.to_csv('../data/df_filtered.csv', index=False)

# %% [markdown]
# <h3 style="color:blue"><b> 4. Groupby </b></h3>

# %%
df_full.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides
# 0            12.0                   167.7
# 1             9.9                    98.9
# 2             9.2                   127.1
# 3             9.7                   177.2
# 4             6.4                   121.8

# %%
# Extract the date (without time) for grouping
df_full['date'] = df_full['date_time'].dt.date

# Group by 'date' and calculate min, max, mean, and count for the 'deg_C' column
df_group = df_full.groupby('date')['deg_C'].agg(
    min_temp=('min'), # Minimum temperature
    max_temp=('max'), # Maximum temperature
    mean_temp=('mean'), # Mean temperature
    count=('count')  # Count of temperature readings
).reset_index()

# drop the 'date' column
df_full.drop(columns=['date'], inplace=True)
df_group
# Out:
#            date  min_temp  max_temp  mean_temp  count
# 0    2010-03-10      11.0      13.2  12.166667      6
# 1    2010-03-11       7.7      11.4   9.762500     24
# 2    2010-03-12       5.7      16.2  11.133333     24
# 3    2010-03-13       6.2      19.0  12.779167     24
# 4    2010-03-14      10.0      22.7  15.800000     24
# ..          ...       ...       ...        ...    ...
# 386  2011-03-31      12.0      23.9  17.583333     24
# 387  2011-04-01      12.6      20.4  15.737500     24
# 388  2011-04-02      10.6      22.6  15.458333     24
# 389  2011-04-03       8.3      30.9  18.341667     24
# 390  2011-04-04       9.1      29.1  16.973333     15
#
# [391 rows x 5 columns]

# %%
# save df_group table
df_group.to_csv('../data/df_group.csv', index=False)

# %% [markdown]
# <h3 style="color:blue"><b> 5. Create a column in df_full </b></h3>

# %%
# A function to map values to classs using a dictionary
def map_to_classs_from_dict(value, split_dict):
    """
    Map a value to a class based on a dictionary of splits.
    Args:
        value: The input value to be mapped to a class.
        split_dict: A dictionary where keys are class labels and values are class ranges.
                  Example: {"class_1": [0, 0.2], "class_2": [0.2, 0.5]}
    Returns:
        The split class the value belongs to.
    """
    for class_label, class_range in split_dict.items():
        if class_range[0] <= value < class_range[1]:  # Check if value falls in the class range
            return class_label
    # Handle the edge case where value equals the upper boundary of the last class
    last_class = list(split_dict.values())[-1]
    if value == last_class[1]:
        return list(split_dict.keys())[-1]
    
# Define the class dictionary
split_dict = {
    "class_1": [0, 0.2],
    "class_2": [0.2, 0.5],
    "class_3": [0.5, 0.8],
    "class_4": [0.8, 0.85],
    "class_5": [0.85, 1],
}

# Normalize the columns
df_full["sensor_1_norm"] = df_full["sensor_1"] / df_full["sensor_1"].max()
df_full["sensor_2_norm"] = df_full["sensor_2"] / df_full["sensor_2"].max()

# Apply the function to create new columns
df_full["Truth"] = df_full["sensor_1_norm"].apply(map_to_classs_from_dict, split_dict=split_dict)
df_full["Predicted"] = df_full["sensor_2_norm"].apply(map_to_classs_from_dict, split_dict=split_dict)

df_full.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides  sensor_1_norm  sensor_2_norm  \
# 0            12.0                   167.7       0.664272       0.472422
# 1             9.9                    98.9       0.612508       0.385738
# 2             9.2                   127.1       0.637792       0.403718
# 3             9.7                   177.2       0.632572       0.403457
# 4             6.4                   121.8       0.609108       0.370321
#
#      Truth Predicted
# 0  class_3   class_2
# 1  class_3   class_2
# 2  class_3   class_2
# 3  class_3   class_2
# 4  class_3   class_2

# %% [markdown]
# <h3 style="color:blue"><b> 6. Merge </b></h3>

# %%
df_full.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides  sensor_1_norm  sensor_2_norm  \
# 0            12.0                   167.7       0.664272       0.472422
# 1             9.9                    98.9       0.612508       0.385738
# 2             9.2                   127.1       0.637792       0.403718
# 3             9.7                   177.2       0.632572       0.403457
# 4             6.4                   121.8       0.609108       0.370321
#
#      Truth Predicted
# 0  class_3   class_2
# 1  class_3   class_2
# 2  class_3   class_2
# 3  class_3   class_2
# 4  class_3   class_2

# %%
# Add 'month_day' column to represent the day and month (ignoring year)
df_full['month_day'] = df_full['date_time'].dt.strftime('%m-%d')  # Format: 'MM-DD'
df_full['month_day']
# Out:
# 0       03-10
# 1       03-10
# 2       03-10
# 3       03-10
# 4       03-10
#         ...
# 9353    04-04
# 9354    04-04
# 9355    04-04
# 9356    04-04
# 9357    04-04
# Name: month_day, Length: 9358, dtype: object

# %%
# Filter for the year 2010 and 2011
df_year1 = df_full[df_full['date_time'].dt.year == 2010]
df_year2 = df_full[df_full['date_time'].dt.year == 2011]

# %%
df_year2.head()
# Out:
#                date_time  deg_C  relative_humidity  absolute_humidity  \
# 7110 2011-01-01 00:00:00    8.0               41.3             0.4375
# 7111 2011-01-01 00:00:00    8.0               41.3             0.4375
# 7112 2011-01-01 01:00:00    5.1               51.7             0.4564
# 7113 2011-01-01 02:00:00    5.8               51.5             0.4689
# 7114 2011-01-01 03:00:00    5.0               52.3             0.4693
#
#       sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 7110    1108.8     745.7     797.1     880.0    1273.1
# 7111    1108.8     745.7     797.1     880.0    1273.1
# 7112    1249.5     864.9     687.9     972.8    1714.0
# 7113    1102.6     878.0     693.7     941.9    1300.8
# 7114    1139.7     916.2     725.6    1011.0    1283.0
#
#       target_carbon_monoxide  target_benzene  target_nitrogen_oxides  \
# 7110                     1.4             4.1                   186.5
# 7111                     0.6            10.3                   217.4
# 7112                     1.6             8.6                    40.0
# 7113                     0.3             2.4                   411.1
# 7114                     3.1             1.9                   191.8
#
#       sensor_1_norm  sensor_2_norm    Truth Predicted month_day
# 7110       0.530958       0.323851  class_3   class_2     01-01
# 7111       0.530958       0.323851  class_3   class_2     01-01
# 7112       0.598334       0.375619  class_3   class_2     01-01
# 7113       0.527989       0.381308  class_3   class_2     01-01
# 7114       0.545755       0.397898  class_3   class_2     01-01

# %% [markdown]
# <span style="color:red">**Overlapp days between the two years (2010 and 2011)**</span>

# %%
# Unique days in the year 2010
unique_days_year1 = df_year1['month_day'].unique()
unique_days_year1
# Out:
# array(['03-10', '03-11', '03-12', '03-13', '03-14', '03-15', '03-16',
#        '03-17', '03-18', '03-19', '03-20', '03-21', '03-22', '03-23',
#        '03-24', '03-25', '03-26', '03-27', '03-28', '03-29', '03-30',
#        '03-31', '04-01', '04-02', '04-03', '04-04', '04-05', '04-06',
#        '04-07', '04-08', '04-09', '04-10', '04-11', '04-12', '04-13',
#        '04-14', '04-15', '04-16', '04-17', '04-18', '04-19', '04-20',
#        '04-21', '04-22', '04-23', '04-24', '04-25', '04-26', '04-27',
#        '04-28', '04-29', '04-30', '05-01', '05-02', '05-03', '05-04',
#        '05-05', '05-06', '05-07', '05-08', '05-09', '05-10', '05-11',
#        '05-12', '05-13', '05-14', '05-15', '05-16', '05-17', '05-18',
#        '05-19', '05-20', '05-21', '05-22', '05-23', '05-24', '05-25',
#        '05-26', '05-27', '05-28', '05-29', '05-30', '05-31', '06-01',
#        '06-02', '06-03', '06-04', '06-05', '06-06', '06-07', '06-08',
#        '06-09', '06-10', '06-11', '06-12', '06-13', '06-14', '06-15',
#        '06-16', '06-17', '06-18', '06-19', '06-20', '06-21', '06-22',
#        '06-23', '06-24', '06-25', '06-26', '06-27', '06-28', '06-29',
#        '06-30', '07-01', '07-02', '07-03', '07-04', '07-05', '07-06',
#        '07-07', '07-08', '07-09', '07-10', '07-11', '07-12', '07-13',
#        '07-14', '07-15', '07-16', '07-17', '07-18', '07-19', '07-20',
#        '07-21', '07-22', '07-23', '07-24', '07-25', '07-26', '07-27',
#        '07-28', '07-29', '07-30', '07-31', '08-01', '08-02', '08-03',
#        '08-04', '08-05', '08-06', '08-07', '08-08', '08-09', '08-10',
#        '08-11', '08-12', '08-13', '08-14', '08-15', '08-16', '08-17',
#        '08-18', '08-19', '08-20', '08-21', '08-22', '08-23', '08-24',
#        '08-25', '08-26', '08-27', '08-28', '08-29', '08-30', '08-31',
#        '09-01', '09-02', '09-03', '09-04', '09-05', '09-06', '09-07',
#        '09-08', '09-09', '09-10', '09-11', '09-12', '09-13', '09-14',
#        '09-15', '09-16', '09-17', '09-18', '09-19', '09-20', '09-21',
#        '09-22', '09-23', '09-24', '09-25', '09-26', '09-27', '09-28',
#        '09-29', '09-30', '10-01', '10-02', '10-03', '10-04', '10-05',
#        '10-06', '10-07', '10-08', '10-09', '10-10', '10-11', '10-12',
#        '10-13', '10-14', '10-15', '10-16', '10-17', '10-18', '10-19',
#        '10-20', '10-21', '10-22', '10-23', '10-24', '10-25', '10-26',
#        '10-27', '10-28', '10-29', '10-30', '10-31', '11-01', '11-02',
#        '11-03', '11-04', '11-05', '11-06', '11-07', '11-08', '11-09',
#        '11-10', '11-11', '11-12', '11-13', '11-14', '11-15', '11-16',
#        '11-17', '11-18', '11-19', '11-20', '11-21', '11-22', '11-23',
#        '11-24', '11-25', '11-26', '11-27', '11-28', '11-29', '11-30',
#        '12-01', '12-02', '12-03', '12-04', '12-05', '12-06', '12-07',
#        '12-08', '12-09', '12-10', '12-11', '12-12', '12-13', '12-14',
#        '12-15', '12-16', '12-17', '12-18', '12-19', '12-20', '12-21',
#        '12-22', '12-23', '12-24', '12-25', '12-26', '12-27', '12-28',
#        '12-29', '12-30', '12-31'], dtype=object)

# %%
# Unique days in the year 2011
unique_days_year2 = df_year2['month_day'].unique()
unique_days_year2
# Out:
# array(['01-01', '01-02', '01-03', '01-04', '01-05', '01-06', '01-07',
#        '01-08', '01-09', '01-10', '01-11', '01-12', '01-13', '01-14',
#        '01-15', '01-16', '01-17', '01-18', '01-19', '01-20', '01-21',
#        '01-22', '01-23', '01-24', '01-25', '01-26', '01-27', '01-28',
#        '01-29', '01-30', '01-31', '02-01', '02-02', '02-03', '02-04',
#        '02-05', '02-06', '02-07', '02-08', '02-09', '02-10', '02-11',
#        '02-12', '02-13', '02-14', '02-15', '02-16', '02-17', '02-18',
#        '02-19', '02-20', '02-21', '02-22', '02-23', '02-24', '02-25',
#        '02-26', '02-27', '02-28', '03-01', '03-02', '03-03', '03-04',
#        '03-05', '03-06', '03-07', '03-08', '03-09', '03-10', '03-11',
#        '03-12', '03-13', '03-14', '03-15', '03-16', '03-17', '03-18',
#        '03-19', '03-20', '03-21', '03-22', '03-23', '03-24', '03-25',
#        '03-26', '03-27', '03-28', '03-29', '03-30', '03-31', '04-01',
#        '04-02', '04-03', '04-04'], dtype=object)

# %%
# overlapping days
overlapping_days = set(unique_days_year1).intersection(unique_days_year2)
overlapping_days
# Out:
# {'03-10',
#  '03-11',
#  '03-12',
#  '03-13',
#  '03-14',
#  '03-15',
#  '03-16',
#  '03-17',
#  '03-18',
#  '03-19',
#  '03-20',
#  '03-21',
#  '03-22',
#  '03-23',
#  '03-24',
#  '03-25',
#  '03-26',
#  '03-27',
#  '03-28',
#  '03-29',
#  '03-30',
#  '03-31',
#  '04-01',
#  '04-02',
#  '04-03',
#  '04-04'}

# %%
# Number of overlapping days
print(f'Number of overlapping days: {len(overlapping_days)}')
# Out:
# Number of overlapping days: 26

# %% [markdown]
# <span style="color:red">**Daily difference average of absolute humidity**</span>

# %% [markdown]
# <span>The overlapping days have varying numbers of entries in each year, with multiple daily values recorded. To accurately compare daily values across years for these overlapping days, we first compute the daily average for each day in both years</span>

# %%
# Aggregate absolute_humidity by day for each year
df_year1_daily = df_year1.groupby('month_day', as_index=False)['absolute_humidity'].mean()
df_year2_daily = df_year2.groupby('month_day', as_index=False)['absolute_humidity'].mean()

# %%
df_year1_daily.head()
# Out:
#   month_day  absolute_humidity
# 0     03-10           0.765633
# 1     03-11           0.775767
# 2     03-12           0.663104
# 3     03-13           0.732296
# 4     03-14           0.849671

# %%
df_year2_daily.head()
# Out:
#   month_day  absolute_humidity
# 0     01-01           0.496512
# 1     01-02           0.527963
# 2     01-03           0.233875
# 3     01-04           0.233537
# 4     01-05           0.854258

# %%
# Merge the daily averages for overlapping days
df_daily_merged = pd.merge(
    df_year1_daily,
    df_year2_daily,
    on='month_day',
    suffixes=('_year1', '_year2')
)

print(len(df_daily_merged))
df_daily_merged.head()
# Out:
# 26
#   month_day  absolute_humidity_year1  absolute_humidity_year2
# 0     03-10                 0.765633                 0.543837
# 1     03-11                 0.775767                 0.563583
# 2     03-12                 0.663104                 0.764592
# 3     03-13                 0.732296                 0.807121
# 4     03-14                 0.849671                 0.822033

# %%
# daily difference in absolute humidity
df_daily_merged['abs_humidity_diff'] = abs(df_daily_merged['absolute_humidity_year1'] - df_daily_merged['absolute_humidity_year2'])

df_daily_merged.head()
# Out:
#   month_day  absolute_humidity_year1  absolute_humidity_year2  \
# 0     03-10                 0.765633                 0.543837
# 1     03-11                 0.775767                 0.563583
# 2     03-12                 0.663104                 0.764592
# 3     03-13                 0.732296                 0.807121
# 4     03-14                 0.849671                 0.822033
#
#    abs_humidity_diff
# 0           0.221796
# 1           0.212183
# 2           0.101487
# 3           0.074825
# 4           0.027637

# %%
# average of the daily differences
avg_abs_humidity_diff = df_daily_merged['abs_humidity_diff'].mean()

print(f"Average daily difference of absolute humidity: {avg_abs_humidity_diff:.2f}")
# Out:
# Average daily difference of absolute humidity: 0.22

# %% [markdown]
# <h3 style="color:blue"><b> 7. Plots on df_full </b></h3>

# %% [markdown]
# <span style="color:red">**Histogram of absolute humidity**</span>

# %%
df_full.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides  sensor_1_norm  sensor_2_norm  \
# 0            12.0                   167.7       0.664272       0.472422
# 1             9.9                    98.9       0.612508       0.385738
# 2             9.2                   127.1       0.637792       0.403718
# 3             9.7                   177.2       0.632572       0.403457
# 4             6.4                   121.8       0.609108       0.370321
#
#      Truth Predicted month_day
# 0  class_3   class_2     03-10
# 1  class_3   class_2     03-10
# 2  class_3   class_2     03-10
# 3  class_3   class_2     03-10
# 4  class_3   class_2     03-10

# %%
# histogram of absolute humidity
df_full['absolute_humidity'].hist()
# Out:
# <Axes: >

# %%
# sensor_1 to sensor_5 histogram overlaid on same figure
df_full[['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5']].plot(kind='hist', alpha=0.7, bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# scatter plot of sensor_1 vs sensor_2 colored blue if weekday, red otherwise
weekday_color = np.where(df_full['date_time'].dt.weekday < 5, 'blue', 'red')
df_full.plot.scatter(x='sensor_1', y='sensor_2', c=weekday_color)
# add labels and title
plt.xlabel('Sensor 1')
plt.ylabel('Sensor 2')
plt.title('Sensor 1 vs Sensor 2')
# legend
plt.legend(['Weekday', 'Weekend'])
# display the plot
plt.show()

# %%
# correlation matrix of all sensors against each other with histogram of the sensor values along the diagonal
sensor_cols = ['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5']
sensor_corr = df_full[sensor_cols].corr()

# Plot the correlation matrix
fig, ax = plt.subplots()
cax = ax.matshow(sensor_corr, cmap='coolwarm')
fig.colorbar(cax)

# Set the x-axis labels
ax.set_xticks(range(len(sensor_cols)))
ax.set_xticklabels(sensor_cols)

# Set the y-axis labels
ax.set_yticks(range(len(sensor_cols)))
ax.set_yticklabels(sensor_cols)

# Display the plot
plt.show()

# %%
# confusion matrix of predicted vs truth using seaborn
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Create the confusion matrix
conf_matrix = confusion_matrix(df_full['Truth'], df_full['Predicted'])

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# <h3 style="color:blue"><b> 8. Create data split </b></h3>

# %%
df_1.head()
# Out:
#              date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0  2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1  2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2  2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3  2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4  2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides
# 0            12.0                   167.7
# 1             9.9                    98.9
# 2             9.2                   127.1
# 3             9.7                   177.2
# 4             6.4                   121.8

# %%
# df_1 is the original train dataset
df_1['date_time'] = pd.to_datetime(df_1['date_time'])
# extracting the day as unique days
df_1['day'] = df_1['date_time'].dt.date
unique_days = df_1['day'].unique()
np.random.seed(42)  # Set seed for reproducibility
# split into train and val having unique with train having 70%
train_days = np.random.choice(unique_days, size=int(0.7 * len(unique_days)), replace=False)  # 70% random sample
val_days = np.setdiff1d(unique_days, train_days)  # Remaining 30% for validation

# %%
train_days
# Out:
# array([datetime.date(2010, 8, 16), datetime.date(2010, 11, 29),
#        datetime.date(2010, 11, 19), datetime.date(2010, 3, 19),
#        datetime.date(2010, 5, 26), datetime.date(2010, 10, 30),
#        datetime.date(2010, 6, 11), datetime.date(2010, 6, 27),
#        datetime.date(2010, 3, 15), datetime.date(2010, 8, 29),
#        datetime.date(2010, 6, 15), datetime.date(2010, 9, 20),
#        datetime.date(2010, 9, 9), datetime.date(2010, 8, 11),
#        datetime.date(2010, 5, 6), datetime.date(2010, 5, 9),
#        datetime.date(2010, 8, 4), datetime.date(2010, 6, 26),
#        datetime.date(2010, 5, 12), datetime.date(2010, 7, 28),
#        datetime.date(2010, 8, 12), datetime.date(2010, 6, 22),
#        datetime.date(2010, 11, 11), datetime.date(2010, 4, 25),
#        datetime.date(2010, 4, 21), datetime.date(2010, 8, 25),
#        datetime.date(2010, 12, 14), datetime.date(2010, 7, 4),
#        datetime.date(2010, 10, 22), datetime.date(2010, 12, 12),
#        datetime.date(2010, 3, 27), datetime.date(2010, 12, 17),
#        datetime.date(2010, 4, 12), datetime.date(2010, 4, 3),
#        datetime.date(2010, 4, 24), datetime.date(2010, 3, 17),
#        datetime.date(2010, 7, 1), datetime.date(2010, 9, 19),
#        datetime.date(2010, 6, 29), datetime.date(2010, 6, 10),
#        datetime.date(2010, 5, 24), datetime.date(2010, 5, 31),
#        datetime.date(2010, 7, 6), datetime.date(2010, 5, 25),
#        datetime.date(2010, 7, 17), datetime.date(2010, 9, 22),
#        datetime.date(2010, 10, 5), datetime.date(2010, 12, 22),
#        datetime.date(2010, 9, 12), datetime.date(2010, 9, 3),
#        datetime.date(2010, 8, 1), datetime.date(2010, 9, 11),
#        datetime.date(2010, 6, 2), datetime.date(2010, 11, 12),
#        datetime.date(2010, 12, 16), datetime.date(2010, 5, 22),
#        datetime.date(2010, 10, 24), datetime.date(2010, 4, 4),
#        datetime.date(2010, 10, 4), datetime.date(2010, 5, 8),
#        datetime.date(2010, 3, 16), datetime.date(2010, 9, 8),
#        datetime.date(2010, 8, 27), datetime.date(2010, 8, 3),
#        datetime.date(2010, 4, 9), datetime.date(2010, 4, 1),
#        datetime.date(2010, 11, 18), datetime.date(2010, 5, 5),
#        datetime.date(2010, 10, 7), datetime.date(2010, 12, 19),
#        datetime.date(2010, 7, 14), datetime.date(2010, 11, 1),
#        datetime.date(2010, 12, 2), datetime.date(2010, 9, 26),
#        datetime.date(2010, 8, 15), datetime.date(2010, 10, 20),
#        datetime.date(2010, 5, 27), datetime.date(2010, 5, 15),
#        datetime.date(2010, 12, 30), datetime.date(2010, 12, 15),
#        datetime.date(2010, 8, 30), datetime.date(2010, 3, 29),
#        datetime.date(2010, 12, 9), datetime.date(2010, 5, 28),
#        datetime.date(2010, 6, 8), datetime.date(2010, 7, 20),
#        datetime.date(2010, 5, 21), datetime.date(2010, 3, 25),
#        datetime.date(2010, 3, 20), datetime.date(2010, 8, 14),
#        datetime.date(2010, 10, 19), datetime.date(2010, 5, 17),
#        datetime.date(2010, 10, 17), datetime.date(2010, 4, 16),
#        datetime.date(2010, 3, 26), datetime.date(2010, 7, 7),
#        datetime.date(2010, 11, 7), datetime.date(2010, 12, 3),
#        datetime.date(2010, 5, 16), datetime.date(2010, 6, 19),
#        datetime.date(2010, 5, 18), datetime.date(2010, 4, 10),
#        datetime.date(2010, 9, 10), datetime.date(2010, 8, 5),
#        datetime.date(2010, 10, 18), datetime.date(2010, 7, 2),
#        datetime.date(2010, 3, 28), datetime.date(2010, 9, 4),
#        datetime.date(2010, 6, 14), datetime.date(2010, 8, 21),
#        datetime.date(2010, 12, 25), datetime.date(2010, 6, 4),
#        datetime.date(2010, 11, 10), datetime.date(2010, 7, 31),
#        datetime.date(2010, 9, 30), datetime.date(2010, 7, 12),
#        datetime.date(2010, 7, 27), datetime.date(2010, 8, 9),
#        datetime.date(2010, 9, 29), datetime.date(2010, 5, 4),
#        datetime.date(2010, 9, 24), datetime.date(2010, 9, 7),
#        datetime.date(2010, 9, 5), datetime.date(2010, 7, 25),
#        datetime.date(2010, 11, 15), datetime.date(2010, 4, 17),
#        datetime.date(2010, 7, 13), datetime.date(2010, 9, 18),
#        datetime.date(2010, 11, 28), datetime.date(2010, 9, 28),
#        datetime.date(2010, 6, 30), datetime.date(2010, 8, 22),
#        datetime.date(2010, 7, 5), datetime.date(2010, 12, 10),
#        datetime.date(2010, 12, 4), datetime.date(2010, 11, 9),
#        datetime.date(2010, 9, 1), datetime.date(2010, 3, 12),
#        datetime.date(2010, 7, 3), datetime.date(2010, 9, 2),
#        datetime.date(2010, 9, 6), datetime.date(2010, 7, 8),
#        datetime.date(2010, 10, 21), datetime.date(2010, 11, 23),
#        datetime.date(2010, 7, 15), datetime.date(2010, 5, 23),
#        datetime.date(2010, 4, 8), datetime.date(2010, 6, 1),
#        datetime.date(2010, 11, 5), datetime.date(2010, 6, 25),
#        datetime.date(2010, 12, 21), datetime.date(2010, 10, 11),
#        datetime.date(2010, 11, 14), datetime.date(2010, 10, 14),
#        datetime.date(2010, 10, 9), datetime.date(2010, 5, 14),
#        datetime.date(2010, 9, 21), datetime.date(2010, 6, 3),
#        datetime.date(2010, 10, 6), datetime.date(2010, 3, 22),
#        datetime.date(2010, 4, 14), datetime.date(2010, 4, 7),
#        datetime.date(2010, 7, 30), datetime.date(2010, 12, 28),
#        datetime.date(2010, 11, 16), datetime.date(2010, 8, 24),
#        datetime.date(2010, 4, 30), datetime.date(2010, 6, 13),
#        datetime.date(2010, 10, 26), datetime.date(2010, 11, 25),
#        datetime.date(2010, 4, 20), datetime.date(2010, 6, 7),
#        datetime.date(2010, 10, 25), datetime.date(2010, 7, 24),
#        datetime.date(2010, 4, 5), datetime.date(2010, 12, 26),
#        datetime.date(2010, 7, 29), datetime.date(2010, 9, 23),
#        datetime.date(2010, 3, 10), datetime.date(2010, 12, 1),
#        datetime.date(2010, 12, 7), datetime.date(2010, 6, 18),
#        datetime.date(2010, 12, 18), datetime.date(2010, 12, 13),
#        datetime.date(2010, 8, 28), datetime.date(2010, 6, 16),
#        datetime.date(2010, 4, 15), datetime.date(2010, 5, 10),
#        datetime.date(2010, 8, 7), datetime.date(2010, 10, 29),
#        datetime.date(2010, 10, 27), datetime.date(2010, 11, 4),
#        datetime.date(2010, 3, 21), datetime.date(2010, 12, 29),
#        datetime.date(2010, 11, 30), datetime.date(2010, 4, 6),
#        datetime.date(2010, 10, 15), datetime.date(2010, 3, 14),
#        datetime.date(2010, 7, 10), datetime.date(2010, 4, 11),
#        datetime.date(2010, 11, 3), datetime.date(2010, 8, 19),
#        datetime.date(2010, 10, 2), datetime.date(2010, 11, 20),
#        datetime.date(2010, 7, 26), datetime.date(2010, 5, 11),
#        datetime.date(2010, 7, 23), datetime.date(2010, 7, 16)],
#       dtype=object)

# %%
val_days
# Out:
# array([datetime.date(2010, 3, 11), datetime.date(2010, 3, 13),
#        datetime.date(2010, 3, 18), datetime.date(2010, 3, 23),
#        datetime.date(2010, 3, 24), datetime.date(2010, 3, 30),
#        datetime.date(2010, 3, 31), datetime.date(2010, 4, 2),
#        datetime.date(2010, 4, 13), datetime.date(2010, 4, 18),
#        datetime.date(2010, 4, 19), datetime.date(2010, 4, 22),
#        datetime.date(2010, 4, 23), datetime.date(2010, 4, 26),
#        datetime.date(2010, 4, 27), datetime.date(2010, 4, 28),
#        datetime.date(2010, 4, 29), datetime.date(2010, 5, 1),
#        datetime.date(2010, 5, 2), datetime.date(2010, 5, 3),
#        datetime.date(2010, 5, 7), datetime.date(2010, 5, 13),
#        datetime.date(2010, 5, 19), datetime.date(2010, 5, 20),
#        datetime.date(2010, 5, 29), datetime.date(2010, 5, 30),
#        datetime.date(2010, 6, 5), datetime.date(2010, 6, 6),
#        datetime.date(2010, 6, 9), datetime.date(2010, 6, 12),
#        datetime.date(2010, 6, 17), datetime.date(2010, 6, 20),
#        datetime.date(2010, 6, 21), datetime.date(2010, 6, 23),
#        datetime.date(2010, 6, 24), datetime.date(2010, 6, 28),
#        datetime.date(2010, 7, 9), datetime.date(2010, 7, 11),
#        datetime.date(2010, 7, 18), datetime.date(2010, 7, 19),
#        datetime.date(2010, 7, 21), datetime.date(2010, 7, 22),
#        datetime.date(2010, 8, 2), datetime.date(2010, 8, 6),
#        datetime.date(2010, 8, 8), datetime.date(2010, 8, 10),
#        datetime.date(2010, 8, 13), datetime.date(2010, 8, 17),
#        datetime.date(2010, 8, 18), datetime.date(2010, 8, 20),
#        datetime.date(2010, 8, 23), datetime.date(2010, 8, 26),
#        datetime.date(2010, 8, 31), datetime.date(2010, 9, 13),
#        datetime.date(2010, 9, 14), datetime.date(2010, 9, 15),
#        datetime.date(2010, 9, 16), datetime.date(2010, 9, 17),
#        datetime.date(2010, 9, 25), datetime.date(2010, 9, 27),
#        datetime.date(2010, 10, 1), datetime.date(2010, 10, 3),
#        datetime.date(2010, 10, 8), datetime.date(2010, 10, 10),
#        datetime.date(2010, 10, 12), datetime.date(2010, 10, 13),
#        datetime.date(2010, 10, 16), datetime.date(2010, 10, 23),
#        datetime.date(2010, 10, 28), datetime.date(2010, 10, 31),
#        datetime.date(2010, 11, 2), datetime.date(2010, 11, 6),
#        datetime.date(2010, 11, 8), datetime.date(2010, 11, 13),
#        datetime.date(2010, 11, 17), datetime.date(2010, 11, 21),
#        datetime.date(2010, 11, 22), datetime.date(2010, 11, 24),
#        datetime.date(2010, 11, 26), datetime.date(2010, 11, 27),
#        datetime.date(2010, 12, 5), datetime.date(2010, 12, 6),
#        datetime.date(2010, 12, 8), datetime.date(2010, 12, 11),
#        datetime.date(2010, 12, 20), datetime.date(2010, 12, 23),
#        datetime.date(2010, 12, 24), datetime.date(2010, 12, 27),
#        datetime.date(2010, 12, 31), datetime.date(2011, 1, 1)],
#       dtype=object)

# %%
# Create the 'train_val_set' column based on the assigned days
df_1['train_val_set'] = df_1['day'].apply(lambda x: 'train' if x in train_days else 'val')
df_1.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides         day train_val_set
# 0            12.0                   167.7  2010-03-10         train
# 1             9.9                    98.9  2010-03-10         train
# 2             9.2                   127.1  2010-03-10         train
# 3             9.7                   177.2  2010-03-10         train
# 4             6.4                   121.8  2010-03-10         train

# %%
df_1['train_val_set'].value_counts()
# Out:
# train_val_set
# train    4974
# val      2137
# Name: count, dtype: int64

# %%
# Number of unique days in each set
df_1[['day', 'train_val_set']].drop_duplicates().train_val_set.value_counts()
# Out:
# train_val_set
# train    208
# val       90
# Name: count, dtype: int64
